# %%
class Synapse:
    def __init__(self, region: str, branch_num: int, branch_iter: int, segment: float):
        self.region = region
        self.branch_num = branch_num
        self.branch_iter = branch_iter
        self.segment = segment

# %%
#import json and mod files

# %%
# soma_diam_um = 40
# soma_length_um = 40

# apic_trunk_diam_um = 5
# apic_trunk_length_um = 50

#clone files from their repo

apic_branch_num = 2
apic_branch_iter = 3
# apic_total_length_um = 300


basal_branch_num = 2
basal_branch_iter = 3
# basal_total_length_um = 300

#user provides file

#FIRST TODO: GET THIS WORKING!
synapse_list = [
Synapse('Apical', 1, 1, .5)
Synapse('Apical', 2, 1, .5)
Synapse('Apical', 3, 1, .5)
]



#synapses

#conductances

#synapse: modfile
#fi: csv?
#passive properties: just write in here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6fa96b41c68f> in <cell line: 0>()
#      14 # basal_total_length_um = 300
#      15
# ---> 16 Synapse('basal', 1, 2, .5, file)
#      17
#      18 #synapses
#
# NameError: name 'Synapse' is not defined

# %%
#Transfer resistance
